# %% [markdown]
# # Getting Financial Data - Pandas Datareader

# %% [markdown]
# ### Introduction:
#
# This time you will get data from a website.

# %% [markdown]
# ### Create your time range (start and end variables). The start date should be 01/01/2015 and the end should today (whatever your today is).

# %%
import pandas as pd

# %%
pd.date_range(start=1-1-2015 , end='today')
# Out:
# DatetimeIndex(['1969-12-31 23:59:59.999997985',
#                '1970-01-01 23:59:59.999997985',
#                '1970-01-02 23:59:59.999997985',
#                '1970-01-03 23:59:59.999997985',
#                '1970-01-04 23:59:59.999997985',
#                '1970-01-05 23:59:59.999997985',
#                '1970-01-06 23:59:59.999997985',
#                '1970-01-07 23:59:59.999997985',
#                '1970-01-08 23:59:59.999997985',
#                '1970-01-09 23:59:59.999997985',
#                ...
#                '2022-10-24 23:59:59.999997985',
#                '2022-10-25 23:59:59.999997985',
#                '2022-10-26 23:59:59.999997985',
#                '2022-10-27 23:59:59.999997985',
#                '2022-10-28 23:59:59.999997985',
#                '2022-10-29 23:59:59.999997985',
#                '2022-10-30 23:59:59.999997985',
#                '2022-10-31 23:59:59.999997985',
#                '2022-11-01 23:59:59.999997985',
# ...

# %% [markdown]
# ### Get an API key for one of the APIs that are supported by Pandas Datareader, preferably for AlphaVantage.
#
# If you do not have an API key for any of the supported APIs, it is easiest to get one for [AlphaVantage](https://www.alphavantage.co/support/#api-key). (Note that the API key is shown directly after the signup. You do *not* receive it via e-mail.)
#
# (For a full list of the APIs that are supported by Pandas Datareader, [see here](https://pydata.github.io/pandas-datareader/readers/index.html). As the APIs are provided by third parties, this list may change.)

# %% [markdown]
# ### Use Pandas Datarader to read the daily time series for the Apple stock (ticker symbol AAPL) between 01/01/2015 and today, assign it to df_apple and print it.

# %%
import datetime as dt

# %%
start = ('1-1-2015')
end =('today')

# %%
import pandas_datareader as data

# %%
apple = data.DataReader('AAPL' ,data_source= 'yahoo' ,start=start , end =end)

# %%
apple
# Out:
#                   High         Low        Open       Close       Volume  \
# Date
# 2015-01-02   27.860001   26.837500   27.847500   27.332500  212818400.0
# 2015-01-05   27.162500   26.352501   27.072500   26.562500  257142000.0
# 2015-01-06   26.857500   26.157499   26.635000   26.565001  263188400.0
# 2015-01-07   27.049999   26.674999   26.799999   26.937500  160423600.0
# 2015-01-08   28.037500   27.174999   27.307501   27.972500  237458000.0
# ...                ...         ...         ...         ...          ...
# 2022-10-28  157.500000  147.820007  148.199997  155.740005  164762400.0
# 2022-10-31  154.240005  151.919998  153.160004  153.339996   97943200.0
# 2022-11-01  155.449997  149.130005  155.080002  150.649994   80379300.0
# 2022-11-02  152.169998  145.000000  148.949997  145.029999   93436100.0
# 2022-11-03  142.794998  139.360107  142.059998  140.070007   38578718.0
#
#              Adj Close
# Date
# 2015-01-02   24.644018
# 2015-01-05   23.949757
# ...

# %% [markdown]
# ### Add a new column "stock" to the dataframe and add the ticker symbol

# %%
apple['stock'] = 'AAPL'

# %%
apple.head(5)
# Out:
#                  High        Low       Open      Close       Volume  \
# Date
# 2015-01-02  27.860001  26.837500  27.847500  27.332500  212818400.0
# 2015-01-05  27.162500  26.352501  27.072500  26.562500  257142000.0
# 2015-01-06  26.857500  26.157499  26.635000  26.565001  263188400.0
# 2015-01-07  27.049999  26.674999  26.799999  26.937500  160423600.0
# 2015-01-08  28.037500  27.174999  27.307501  27.972500  237458000.0
#
#             Adj Close stock
# Date
# 2015-01-02  24.644018  AAPL
# 2015-01-05  23.949757  AAPL
# 2015-01-06  23.952009  AAPL
# 2015-01-07  24.287876  AAPL
# 2015-01-08  25.221067  AAPL

# %%
appl_open = apple['Volume'].plot(title = "Apple Stock")


fig = appl_open.get_figure()
fig.set_size_inches(13.5, 9)

# %%
appl_open = apple['Open'].plot(title = "Apple Stock")


fig = appl_open.get_figure()
fig.set_size_inches(13.5, 9)


appl_open = apple['High'].plot(title = "Apple Stock")


fig = appl_open.get_figure()
fig.set_size_inches(13.5, 9)

# %%
appl_open = apple['High'].plot(title = "Apple Stock")


fig = appl_open.get_figure()
fig.set_size_inches(13.5, 9)



appl_open = apple['Close'].plot(title = "Apple Stock")


fig = appl_open.get_figure()
fig.set_size_inches(13.5, 9)

# %% [markdown]
# ### Repeat the two previous steps for a few other stocks, always creating a new dataframe: Tesla, IBM and Microsoft. (Ticker symbols TSLA, IBM and MSFT.)

# %%
TSLA = data.DataReader('TSLA' ,data_source= 'yahoo' ,start=start , end =end)

# %%
TSLA.head()
# Out:
#                  High        Low       Open      Close      Volume  Adj Close
# Date
# 2015-01-02  14.883333  14.217333  14.858000  14.620667  71466000.0  14.620667
# 2015-01-05  14.433333  13.810667  14.303333  14.006000  80527500.0  14.006000
# 2015-01-06  14.280000  13.614000  14.004000  14.085333  93928500.0  14.085333
# 2015-01-07  14.318667  13.985333  14.223333  14.063333  44526000.0  14.063333
# 2015-01-08  14.253333  14.000667  14.187333  14.041333  51637500.0  14.041333

# %%
TSLA['stock'] = 'TSLA'

# %%
TSLA.tail()
# Out:
#                   High         Low        Open       Close      Volume  \
# Date
# 2022-10-28  228.860001  216.350006  225.399994  228.520004  69152400.0
# 2022-10-31  229.850006  221.940002  226.190002  227.539993  61554300.0
# 2022-11-01  237.399994  227.279999  234.050003  227.820007  62688800.0
# 2022-11-02  227.869995  214.820007  226.039993  214.979996  62887200.0
# 2022-11-03  221.192505  210.149994  211.360001  218.029999  26864160.0
#
#              Adj Close stock
# Date
# 2022-10-28  228.520004  TSLA
# 2022-10-31  227.539993  TSLA
# 2022-11-01  227.820007  TSLA
# 2022-11-02  214.979996  TSLA
# 2022-11-03  218.029999  TSLA

# %%
TSLA_open = TSLA['Volume'].plot(title = "TSLA Stock")


fig = TSLA_open.get_figure()
fig.set_size_inches(13.5, 9)

# %%
TSLA_open = TSLA['Close'].plot(title = "TSLA Stock")


fig = TSLA_open.get_figure()
fig.set_size_inches(13.5, 9)


TSLA_open = TSLA['High'].plot(title = "TSLA Stock" , color ='red')


fig = TSLA_open.get_figure()
fig.set_size_inches(13.5, 9)

# %%
TSLA_open = TSLA['Adj Close'].plot(title = "TSLA Stock")


fig = TSLA_open.get_figure()
fig.set_size_inches(13.5, 9)

TSLA_open = TSLA['High'].plot(title = "TSLA Stock")


fig = TSLA_open.get_figure()
fig.set_size_inches(13.5, 9)

# %%
IBM = data.DataReader('IBM' ,data_source= 'yahoo' ,start=start , end =end)

# %%
IBM['stock'] = 'IBM'

# %%
IBM.head()
# Out:
#                   High         Low        Open       Close     Volume  \
# Date
# 2015-01-02  156.128113  153.919693  154.216064  154.933075  5779673.0
# 2015-01-05  154.177826  152.189301  154.177826  152.495224  5104898.0
# 2015-01-06  152.925430  148.346085  152.648178  149.206497  6429448.0
# 2015-01-07  150.286804  147.256210  150.286804  148.231354  4918083.0
# 2015-01-08  152.045883  148.709366  149.369019  151.453156  4431693.0
#
#              Adj Close stock
# Date
# 2015-01-02  110.782295   IBM
# 2015-01-05  109.039169   IBM
# 2015-01-06  106.687614   IBM
# 2015-01-07  105.990364   IBM
# 2015-01-08  108.294044   IBM

# %%
IBM_open = IBM['Volume'].plot(title = "IBM STOCK")


fig = IBM_open.get_figure()
fig.set_size_inches(13.5, 9)

# %%
IBM_open = IBM['Close'].plot(title = "IBM STOCK")


fig = IBM_open.get_figure()
fig.set_size_inches(13.5, 9)


IBM_open = IBM['Adj Close'].plot(title = "IBM STOCK", color= 'green')


fig = IBM_open.get_figure()
fig.set_size_inches(13.5, 9)

# %%
IBM_open = IBM['High'].plot(title = "IBM STOCK")


fig = IBM_open.get_figure()
fig.set_size_inches(13.5, 9)

IBM_open = IBM['Adj Close'].plot(title = "IBM STOCK")


fig = IBM_open.get_figure()
fig.set_size_inches(13.5, 9)

# %%
MSFT = data.DataReader('AAPL' ,data_source= 'yahoo' ,start=start , end =end)

# %%
MSFT.head()
# Out:
#                  High        Low       Open      Close       Volume  Adj Close
# Date
# 
# ### Create a dataFrame called vol, with the volume values.

# %%
volume = stock_data['Volume']

# %%
volume.head(7)
# Out:
# Date        stock
# 2015-01-02  AAPL     212818400.0
# 2015-01-05  AAPL     257142000.0
# 2015-01-06  AAPL     263188400.0
# 2015-01-07  AAPL     160423600.0
# 2015-01-08  AAPL     237458000.0
# 2015-01-09  AAPL     214798000.0
# 2015-01-12  AAPL     198603200.0
# Name: Volume, dtype: float64

# %% [markdown]
# ### Aggregate the data of volume to weekly.
# Hint: Be careful to not sum data from the same week of 2015 and other years.

# %%
stock_data=stock_data.reset_index()

# %%
stock_data
# Out:
#            Date stock        High         Low        Open       Close  \
# 0    2015-01-02  AAPL   27.860001   26.837500   27.847500   27.332500
# 1    2015-01-05  AAPL   27.162500   26.352501   27.072500   26.562500
# 2    2015-01-06  AAPL   26.857500   26.157499   26.635000   26.565001
# 3    2015-01-07  AAPL   27.049999   26.674999   26.799999   26.937500
# 4    2015-01-08  AAPL   28.037500   27.174999   27.307501   27.972500
# ...         ...   ...         ...         ...         ...         ...
# 7895 2022-10-28  MSFT  157.500000  147.820007  148.199997  155.740005
# 7896 2022-10-31  MSFT  154.240005  151.919998  153.160004  153.339996
# 7897 2022-11-01  MSFT  155.449997  149.130005  155.080002  150.649994
# 7898 2022-11-02  MSFT  152.169998  145.000000  148.949997  145.029999
# 7899 2022-11-03  MSFT  142.794998  139.360107  142.059998  140.035004
#
#            Volume   Adj Close
# 0     212818400.0   24.644018
# 1     257142000.0   23.949757
# 2     263188400.0   23.952009
# ...

# %%
stock_data =stock_data.set_index('Date')

# %%
stock_data
# Out:
#            stock        High         Low        Open       Close       Volume  \
# Date
# 2015-01-02  AAPL   27.860001   26.837500   27.847500   27.332500  212818400.0
# 2015-01-05  AAPL   27.162500   26.352501   27.072500   26.562500  257142000.0
# 2015-01-06  AAPL   26.857500   26.157499   26.635000   26.565001  263188400.0
# 2015-01-07  AAPL   27.049999   26.674999   26.799999   26.937500  160423600.0
# 2015-01-08  AAPL   28.037500   27.174999   27.307501   27.972500  237458000.0
# ...          ...         ...         ...         ...         ...          ...
# 2022-10-28  MSFT  157.500000  147.820007  148.199997  155.740005  164762400.0
# 2022-10-31  MSFT  154.240005  151.919998  153.160004  153.339996   97943200.0
# 2022-11-01  MSFT  155.449997  149.130005  155.080002  150.649994   80379300.0
# 2022-11-02  MSFT  152.169998  145.000000  148.949997  145.029999   93436100.0
# 2022-11-03  MSFT  142.794998  139.360107  142.059998  140.035004   39031405.0
#
#              Adj Close
# ...

# %%
stock_data.groupby('stock').resample('W').sum()
# Out:
#                          High          Low         Open        Close  \
# stock Date
# AAPL  2015-01-04    27.860001    26.837500    27.847500    27.332500
#       2015-01-11   137.420000   133.912498   135.982500   136.040001
#       2015-01-18   138.389999   134.517502   137.525000   135.520000
#       2015-01-25   111.562500   109.004999   109.837500   110.912502
#       2015-02-01   146.037502   142.387499   144.627499   143.402500
# ...                       ...          ...          ...          ...
# TSLA  2022-10-09  1238.480011  1173.660004  1223.410004  1193.850006
#       2022-10-16  1121.290009  1055.250000  1092.519989  1083.410019
#       2022-10-23  1104.820007  1050.279999  1074.039993  1083.300003
#       2022-10-30  1131.120010  1065.990005  1090.490005  1111.919998
#       2022-11-06   916.312500   874.190002   897.639999   888.369995
#
#                         Volume    Adj Close
# stock Date
# AAPL  2015-01-04  2.128184e+08    24.644018
# ...

# %%
stock_data =stock_data.groupby('stock').resample('W').Volume.sum().reset_index()

# %%
stock_data
# Out:
#      stock       Date        Volume
# 0     AAPL 2015-01-04  2.128184e+08
# 1     AAPL 2015-01-11  1.133010e+09
# 2     AAPL 2015-01-18  1.216906e+09
# 3     AAPL 2015-01-25  7.949480e+08
# 4     AAPL 2015-02-01  1.863371e+09
# ...    ...        ...           ...
# 1635  TSLA 2022-10-09  4.481399e+08
# 1636  TSLA 2022-10-16  3.974064e+08
# 1637  TSLA 2022-10-23  4.154041e+08
# 1638  TSLA 2022-10-30  4.127584e+08
# 1639  TSLA 2022-11-06  2.139945e+08
#
# [1640 rows x 3 columns]

# %%
volume = stock_data.pivot_table(  values= 'Volume', index= 'Date' , columns= 'stock')

# %%
volume
# Out:
# stock               AAPL         IBM          MSFT         TSLA
# Date
# 2015-01-04  2.128184e+08   5779673.0  2.128184e+08   71466000.0
# 2015-01-11  1.133010e+09  25578884.0  1.133010e+09  340644000.0
# 2015-01-18  1.216906e+09  24329751.0  1.216906e+09  461988000.0
# 2015-01-25  7.949480e+08  32682062.0  7.949480e+08  243175500.0
# 2015-02-01  1.863371e+09  34442689.0  1.863371e+09  235803000.0
# ...                  ...         ...           ...          ...
# 2022-10-09  4.358741e+08  21613500.0  4.358741e+08  448139900.0
# 2022-10-16  4.241027e+08  22971800.0  4.241027e+08  397406400.0
# 2022-10-23  3.971325e+08  37309000.0  3.971325e+08  415404100.0
# 2022-10-30  5.128511e+08  26666200.0  5.128511e+08  412758400.0
# 2022-11-06  3.103373e+08  15364839.0  3.107900e+08  213994460.0
#
# [410 rows x 4 columns]

# %%
volume2 = volume.resample('W').sum()

# %%
volume2
# Out:
# stock               AAPL         IBM          MSFT         TSLA
# Date
# 2015-01-04  2.128184e+08   5779673.0  2.128184e+08   71466000.0
# 2015-01-11  1.133010e+09  25578884.0  1.133010e+09  340644000.0
# 2015-01-18  1.216906e+09  24329751.0  1.216906e+09  461988000.0
# 2015-01-25  7.949480e+08  32682062.0  7.949480e+08  243175500.0
# 2015-02-01  1.863371e+09  34442689.0  1.863371e+09  235803000.0
# ...                  ...         ...           ...          ...
# 2022-10-09  4.358741e+08  21613500.0  4.358741e+08  448139900.0
# 2022-10-16  4.241027e+08  22971800.0  4.241027e+08  397406400.0
# 2022-10-23  3.971325e+08  37309000.0  3.971325e+08  415404100.0
# 2022-10-30  5.128511e+08  26666200.0  5.128511e+08  412758400.0
# 2022-11-06  3.103373e+08  15364839.0  3.107900e+08  213994460.0
#
# [410 rows x 4 columns]

# %% [markdown]
# ### Find all the volume traded in the year of 2015

# %%
volume2.reset_index(inplace=True)

# %%
volume2 =volume2.set_index('Date').resample('Y').sum()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [196], in <cell line: 1>()
# ----> 1 volume2 =volume2.set_index('Date').resample('Y').sum()
#
# File ~\miniconda3\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File ~\miniconda3\lib\site-packages\pandas\core\frame.py:5503, in DataFrame.set_index(self, keys, drop, append, inplace, verify_integrity)
#    5500                 missing.append(col)
#    5502 if missing:
# -> 5503     raise KeyError(f"None of {missing} are in the columns")
#    5505 if inplace:
#    5506     frame = self
#
# ...

# %%
volume2.iloc['2015-12-31']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [193], in <cell line: 1>()
# ----> 1 volume2.iloc['2015-12-31']
#
# File ~\miniconda3\lib\site-packages\pandas\core\indexing.py:967, in _LocationIndexer.__getitem__(self, key)
#     964 axis = self.axis or 0
#     966 maybe_callable = com.apply_if_callable(key, self.obj)
# --> 967 return self._getitem_axis(maybe_callable, axis=axis)
#
# File ~\miniconda3\lib\site-packages\pandas\core\indexing.py:1520, in _iLocIndexer._getitem_axis(self, key, axis)
#    1518 key = item_from_zerodim(key)
#    1519 if not is_integer(key):
# -> 1520     raise TypeError("Cannot index by location index with a non-integer key")
#    1522 # validate the location
#    1523 self._validate_integer(key, axis)
#
# TypeError: Cannot index by location index with a non-integer key
