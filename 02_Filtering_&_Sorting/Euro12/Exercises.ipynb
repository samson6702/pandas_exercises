# %% [markdown]
# # Ex2 - Filtering and Sorting Data

# %% [markdown]
# This time we are going to pull data directly from the internet.

# %% [markdown]
# ### Import the dataset from this [address](https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/02_Filtering_%26_Sorting/Euro12/Euro_2012_stats_TEAM.csv).

# %% [markdown]
# ### Assign it to a variable called euro12.

# %%
import pandas as pd

# %%
euro12 = pd.read_csv('https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/02_Filtering_%26_Sorting/Euro12/Euro_2012_stats_TEAM.csv', sep=',')

# %%
euro12
# Out:
#                    Team  Goals  Shots on target  Shots off target  \
# 0               Croatia      4               13                12
# 1        Czech Republic      4               13                18
# 2               Denmark      4               10                10
# 3               England      5               11                18
# 4                France      3               22                24
# 5               Germany     10               32                32
# 6                Greece      5                8                18
# 7                 Italy      6               34                45
# 8           Netherlands      2               12                36
# 9                Poland      2               15                23
# 10             Portugal      6               22                42
# 11  Republic of Ireland      1                7                12
# 12               Russia      5                9                31
# ...

# %%
euro12.Goals
# Out:
# 0      4
# 1      4
# 2      4
# 3      5
# 4      3
# 5     10
# 6      5
# 7      6
# 8      2
# 9      2
# 10     6
# 11     1
# 12     5
# 13    12
# 14     5
# 15     2
# Name: Goals, dtype: int64

# %%
import matplotlib.pyplot as plt

# %%
(euro12.Goals.value_counts().head(15)).plot(kind ='pie',autopct='%1.1f%%',  legend =False)
# Out:
# <AxesSubplot:ylabel='Goals'>

# %%
X =euro12['Team'].sort_values(ascending=False)
Y =euro12['Goals'].sort_values(ascending=False)
fig = plt.figure(figsize=(10,10))
plt.barh(X,Y)
plt.xlabel('Goal')
plt.ylabel('Team')
fig.autofmt_xdate(bottom= 0.3 ,rotation=30)
plt.show()

# %% [markdown]
# ### Select only the Goal column.

# %% [markdown]
# ### How many team participated in the Euro2012?

# %%
euro12.shape[0]
# Out:
# 16

# %% [markdown]
# ### What is the number of columns in the dataset?

# %%
euro12.shape[1]
# Out:
# 35

# %%
euro12.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16 entries, 0 to 15
# Data columns (total 35 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Team                        16 non-null     object
#  1   Goals                       16 non-null     int64
#  2   Shots on target             16 non-null     int64
#  3   Shots off target            16 non-null     int64
#  4   Shooting Accuracy           16 non-null     object
#  5   % Goals-to-shots            16 non-null     object
#  6   Total shots (inc. Blocked)  16 non-null     int64
#  7   Hit Woodwork                16 non-null     int64
#  8   Penalty goals               16 non-null     int64
#  9   Penalties not scored        16 non-null     int64
#  10  Headed goals                16 non-null     int64
#  11  Passes                      16 non-null     int64
#  12  Passes completed            16 non-null     int64
# ...

# %% [markdown]
# ### View only the columns Team, Yellow Cards and Red Cards and assign them to a dataframe called discipline

# %%
discipline = pd.DataFrame(data= euro12[['Team', 'Yellow Cards', 'Red Cards']])

# %%
discipline
# Out:
#                    Team  Yellow Cards  Red Cards
# 0               Croatia             9          0
# 1        Czech Republic             7          0
# 2               Denmark             4          0
# 3               England             5          0
# 4                France             6          0
# 5               Germany             4          0
# 6                Greece             9          1
# 7                 Italy            16          0
# 8           Netherlands             5          0
# 9                Poland             7          1
# 10             Portugal            12          0
# 11  Republic of Ireland             6          1
# 12               Russia             6          0
# 13                Spain            11          0
# 14               Sweden             7          0
# 15              Ukraine             5          0

# %%
X =euro12['Team'].head(20)
Y =euro12['Yellow Cards'].head(20)
fig = plt.figure(figsize=(10,10))
plt.barh(X,Y)
plt.xlabel('yellow_card')
plt.ylabel('Team')
fig.autofmt_xdate(bottom= 0.3 ,rotation=30)
plt.show()

# %%
(euro12['Yellow Cards'].value_counts().head(16)).plot(kind ='pie',autopct='%1.1f%%',  legend =False)
# Out:
# <AxesSubplot:ylabel='Yellow Cards'>

# %% [markdown]
# ### Sort the teams by Red Cards, then to Yellow Cards

# %%
discipline.sort_values(by=['Red Cards','Yellow Cards'] ,ascending=False)
# Out:
#                    Team  Yellow Cards  Red Cards
# 6                Greece             9          1
# 9                Poland             7          1
# 11  Republic of Ireland             6          1
# 7                 Italy            16          0
# 10             Portugal            12          0
# 13                Spain            11          0
# 0               Croatia             9          0
# 1        Czech Republic             7          0
# 14               Sweden             7          0
# 4                France             6          0
# 12               Russia             6          0
# 3               England             5          0
# 8           Netherlands             5          0
# 15              Ukraine             5          0
# 2               Denmark             4          0
# 5               Germany             4          0

# %%
discipline2 = pd.DataFrame(data=euro12[[ 'Yellow Cards', 'Red Cards']])

# %% [markdown]
# ### Calculate the mean Yellow Cards given per Team

# %%
yellow_cards=discipline['Yellow Cards'].mean()

# %%
round(yellow_cards)
# Out:
# 7

# %% [markdown]
# ### Filter teams that scored more than 6 goals

# %%
euro12[euro12.Goals>6]
# Out:
#        Team  Goals  Shots on target  Shots off target Shooting Accuracy  \
# 5   Germany     10               32                32             47.8%
# 13    Spain     12               42                33             55.9%
#
#    % Goals-to-shots  Total shots (inc. Blocked)  Hit Woodwork  Penalty goals  \
# 5             15.6%                          80             2              1
# 13            16.0%                         100             0              1
#
#     Penalties not scored  ...  Saves made  Saves-to-shots ratio  Fouls Won  \
# 5                      0  ...          10                 62.6%         63
# 13                     0  ...          15                 93.8%        102
#
#    Fouls Conceded  Offsides  Yellow Cards  Red Cards  Subs on  Subs off  \
# 5              49        12             4          0       15        15
# 13             83        19            11          0       17        17
#
#     Players Used
# 5             17
# 13            18
#
# ...

# %% [markdown]
# ### Select the teams that start with G

# %%
euro12[euro12.Team.str.startswith('G')]
# Out:
#       Team  Goals  Shots on target  Shots off target Shooting Accuracy  \
# 5  Germany     10               32                32             47.8%
# 6   Greece      5                8                18             30.7%
#
#   % Goals-to-shots  Total shots (inc. Blocked)  Hit Woodwork  Penalty goals  \
# 5            15.6%                          80             2              1
# 6            19.2%                          32             1              1
#
#    Penalties not scored  ...  Saves made  Saves-to-shots ratio  Fouls Won  \
# 5                     0  ...          10                 62.6%         63
# 6                     1  ...          13                 65.1%         67
#
#   Fouls Conceded  Offsides  Yellow Cards  Red Cards  Subs on  Subs off  \
# 5             49        12             4          0       15        15
# 6             48        12             9          1       12        12
#
#    Players Used
# 5            17
# 6            20
#
# [2 rows x 35 columns]

# %% [markdown]
# ### Select the first 7 columns

# %%
euro12.iloc[: , 0:7]
# Out:
#                    Team  Goals  Shots on target  Shots off target  \
# 0               Croatia      4               13                12
# 1        Czech Republic      4               13                18
# 2               Denmark      4               10                10
# 3               England      5               11                18
# 4                France      3               22                24
# 5               Germany     10               32                32
# 6                Greece      5                8                18
# 7                 Italy      6               34                45
# 8           Netherlands      2               12                36
# 9                Poland      2               15                23
# 10             Portugal      6               22                42
# 11  Republic of Ireland      1                7                12
# 12               Russia      5                9                31
# ...

# %% [markdown]
# ### Select all columns except the last 3.

# %%
euro12.iloc[: , :-3]
# Out:
#                    Team  Goals  Shots on target  Shots off target  \
# 0               Croatia      4               13                12
# 1        Czech Republic      4               13                18
# 2               Denmark      4               10                10
# 3               England      5               11                18
# 4                France      3               22                24
# 5               Germany     10               32                32
# 6                Greece      5                8                18
# 7                 Italy      6               34                45
# 8           Netherlands      2               12                36
# 9                Poland      2               15                23
# 10             Portugal      6               22                42
# 11  Republic of Ireland      1                7                12
# 12               Russia      5                9                31
# ...

# %% [markdown]
# ### Present only the Shooting Accuracy from England, Italy and Russia

# %%
accuracy =euro12.loc[euro12.Team.isin(['England', 'Italy', 'Russia']), ['Team','Shooting Accuracy']]

# %%
accuracy
# Out:
#        Team Shooting Accuracy
# 3   England             50.0%
# 7     Italy             43.0%
# 12   Russia             22.5%

# %%
import matplotlib.pyplot as plt

# %%
Y =euro12['Shooting Accuracy'].sort_values(ascending=True)
X =euro12['Team']
fig = plt.figure(figsize=(12,12))
plt.bar(X,Y)
plt.xlabel('Team')
plt.ylabel('shooting Accuracy')
fig.autofmt_xdate(bottom= 0.3 ,rotation=30)
plt.show()
