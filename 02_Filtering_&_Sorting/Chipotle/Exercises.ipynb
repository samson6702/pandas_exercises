# %% [markdown]
# # Ex1 - Filtering and Sorting Data

# %% [markdown]
# This time we are going to pull data directly from the internet.
# Special thanks to: https://github.com/justmarkham for sharing the dataset and materials.

# %% [markdown]
# ### Import the dataset from this [address](https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv).

# %% [markdown]
# ### Assign it to a variable called chipo.

# %%
import pandas as pd

# %%
url = 'https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv'

chipo = pd.read_csv(url, sep = '\t')

# %% [markdown]
# ### How many products cost more than $10.00?

# %%
prices = [float(value[1 : -1]) for value in chipo.item_price]



chipo.item_price == prices


chipo_filtered = chipo.drop_duplicates(['item_name','quantity','choice_description'])

chipo_one_prod = chipo_filtered[chipo_filtered.quantity == 1]
chipo_one_prod

chipo.query('price_per_iteam> 10').item_name.nunique()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\miniconda3\lib\site-packages\pandas\core\computation\scope.py:197, in Scope.resolve(self, key, is_local)
#     196 if self.has_resolvers:
# --> 197     return self.resolvers[key]
#     199 # if we're here that means that we have no locals and we also have
#     200 # no resolvers
#
# File ~\miniconda3\lib\collections\__init__.py:941, in ChainMap.__getitem__(self, key)
#     940         pass
# --> 941 return self.__missing__(key)
#
# File ~\miniconda3\lib\collections\__init__.py:933, in ChainMap.__missing__(self, key)
#     932 def __missing__(self, key):
# --> 933     raise KeyError(key)
#
# KeyError: 'price_per_iteam'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# File ~\miniconda3\lib\site-packages\pandas\core\computation\scope.py:208, in Scope.resolve(self, key, is_local)
#     204 try:
#     205     # last ditch effort we look in temporaries
#     206     # these are created when parsing indexing expressions
#     207     # e.g., df[df > 0]
# --> 208     return self.temps[key]
#     209 except KeyError as err:
#     210     # runtime import because ops imports from scope
#
# KeyError: 'price_per_iteam'
#
# The above exception was the direct cause of the following exception:
#
# UndefinedVariableError                    Traceback (most recent call last)
# Input In [37], in <cell line: 13>()
#      10 chipo_one_prod = chipo_filtered[chipo_filtered.quantity == 1]
#      11 chipo_one_prod
# ---> 13 chipo.query('price_per_iteam> 10').item_name.nunique()
#
# File ~\miniconda3\lib\site-packages\pandas\core\frame.py:4111, in DataFrame.query(self, expr, inplace, **kwargs)
#    4109 kwargs["level"] = kwargs.pop("level", 0) + 1
#    4110 kwargs["target"] = None
# -> 4111 res = self.eval(expr, **kwargs)
#    4113 try:
#    4114     result = self.loc[res]
#
# File ~\miniconda3\lib\site-packages\pandas\core\frame.py:4240, in DataFrame.eval(self, expr, inplace, **kwargs)
#    4237     kwargs["target"] = self
#    4238 kwargs["resolvers"] = tuple(kwargs.get("resolvers", ())) + resolvers
# -> 4240 return _eval(expr, inplace=inplace, **kwargs)
#
# File ~\miniconda3\lib\site-packages\pandas\core\computation\eval.py:351, in eval(expr, parser, engine, truediv, local_dict, global_dict, resolvers, level, target, inplace)
#     342 # get our (possibly passed-in) scope
#     343 env = ensure_scope(
#     344     level + 1,
#     345     global_dict=global_dict,
#    (...)
#     348     target=target,
#     349 )
# --> 351 parsed_expr = Expr(expr, engine=engine, parser=parser, env=env)
#     353 # construct the engine and evaluate the parsed expression
#     354 eng = ENGINES[engine]
#
# File ~\miniconda3\lib\site-packages\pandas\core\computation\expr.py:811, in Expr.__init__(self, expr, engine, parser, env, level)
#     809 self.parser = parser
#     810 self._visitor = PARSERS[parser](self.env, self.engine, self.parser)
# --> 811 self.terms = self.parse()
#
# File ~\miniconda3\lib\site-packages\pandas\core\computation\expr.py:830, in Expr.parse(self)
#     826 def parse(self):
#     827     """
#     828     Parse an expression.
#     829     """
# --> 830     return self._visitor.visit(self.expr)
#
# File ~\miniconda3\lib\site-packages\pandas\core\computation\expr.py:415, in BaseExprVisitor.visit(self, node, **kwargs)
#     413 method = "visit_" + type(node).__name__
#     414 visitor = getattr(self, method)
# --> 415 return visitor(node, **kwargs)
#
# File ~\miniconda3\lib\site-packages\pandas\core\computation\expr.py:421, in BaseExprVisitor.visit_Module(self, node, **kwargs)
#     419     raise SyntaxError("only a single expression is allowed")
#     420 expr = node.body[0]
# --> 421 return self.visit(expr, **kwargs)
#
# File ~\miniconda3\lib\site-packages\pandas\core\computation\expr.py:415, in BaseExprVisitor.visit(self, node, **kwargs)
#     413 method = "visit_" + type(node).__name__
#     414 visitor = getattr(self, method)
# --> 415 return visitor(node, **kwargs)
#
# File ~\miniconda3\lib\site-packages\pandas\core\computation\expr.py:424, in BaseExprVisitor.visit_Expr(self, node, **kwargs)
#     423 def visit_Expr(self, node, **kwargs):
# --> 424     return self.visit(node.value, **kwargs)
#
# File ~\miniconda3\lib\site-packages\pandas\core\computation\expr.py:415, in BaseExprVisitor.visit(self, node, **kwargs)
#     413 method = "visit_" + type(node).__name__
#     414 visitor = getattr(self, method)
# --> 415 return visitor(node, **kwargs)
#
# File ~\miniconda3\lib\site-packages\pandas\core\computation\expr.py:723, in BaseExprVisitor.visit_Compare(self, node, **kwargs)
#     721     op = self.translate_In(ops[0])
#     722     binop = ast.BinOp(op=op, left=node.left, right=comps[0])
# --> 723     return self.visit(binop)
#     725 # recursive case: we have a chained comparison, a CMP b CMP c, etc.
#     726 left = node.left
#
# File ~\miniconda3\lib\site-packages\pandas\core\computation\expr.py:415, in BaseExprVisitor.visit(self, node, **kwargs)
#     413 method = "visit_" + type(node).__name__
#     414 visitor = getattr(self, method)
# --> 415 return visitor(node, **kwargs)
#
# File ~\miniconda3\lib\site-packages\pandas\core\computation\expr.py:536, in BaseExprVisitor.visit_BinOp(self, node, **kwargs)
#     535 def visit_BinOp(self, node, **kwargs):
# --> 536     op, op_class, left, right = self._maybe_transform_eq_ne(node)
#     537     left, right = self._maybe_downcast_constants(left, right)
#     538     return self._maybe_evaluate_binop(op, op_class, left, right)
#
# File ~\miniconda3\lib\site-packages\pandas\core\computation\expr.py:456, in BaseExprVisitor._maybe_transform_eq_ne(self, node, left, right)
#     454 def _maybe_transform_eq_ne(self, node, left=None, right=None):
#     455     if left is None:
# --> 456         left = self.visit(node.left, side="left")
#     457     if right is None:
#     458         right = self.visit(node.right, side="right")
#
# File ~\miniconda3\lib\site-packages\pandas\core\computation\expr.py:415, in BaseExprVisitor.visit(self, node, **kwargs)
#     413 method = "visit_" + type(node).__name__
#     414 visitor = getattr(self, method)
# --> 415 return visitor(node, **kwargs)
#
# File ~\miniconda3\lib\site-packages\pandas\core\computation\expr.py:549, in BaseExprVisitor.visit_Name(self, node, **kwargs)
#     548 def visit_Name(self, node, **kwargs):
# --> 549     return self.term_type(node.id, self.env, **kwargs)
#
# File ~\miniconda3\lib\site-packages\pandas\core\computation\ops.py:98, in Term.__init__(self, name, env, side, encoding)
#      96 tname = str(name)
#      97 self.is_local = tname.startswith(LOCAL_TAG) or tname in DEFAULT_GLOBALS
# ---> 98 self._value = self._resolve_name()
#      99 self.encoding = encoding
#
# File ~\miniconda3\lib\site-packages\pandas\core\computation\ops.py:115, in Term._resolve_name(self)
#     114 def _resolve_name(self):
# --> 115     res = self.env.resolve(self.local_name, is_local=self.is_local)
#     116     self.update(res)
#     118     if hasattr(res, "ndim") and res.ndim > 2:
#
# File ~\miniconda3\lib\site-packages\pandas\core\computation\scope.py:213, in Scope.resolve(self, key, is_local)
#     209 except KeyError as err:
#     210     # runtime import because ops imports from scope
#     211     from pandas.core.computation.ops import UndefinedVariableError
# --> 213     raise UndefinedVariableError(key, is_local) from err
#
# UndefinedVariableError: name 'price_per_iteam' is not defined

# %% [markdown]
# ### What is the price of each item?
# ###### print a data frame with only two columns item_name and item_price

# %%
chipo[(chipo['item_name'] == 'Chicken Bowl') & (chipo['quantity'] == 1)]
# Out:
#       order_id  quantity     item_name  \
# 5            3         1  Chicken Bowl
# 13           7         1  Chicken Bowl
# 19          10         1  Chicken Bowl
# 26          13         1  Chicken Bowl
# 42          20         1  Chicken Bowl
# ...        ...       ...           ...
# 4590      1825         1  Chicken Bowl
# 4591      1825         1  Chicken Bowl
# 4595      1826         1  Chicken Bowl
# 4599      1827         1  Chicken Bowl
# 4604      1828         1  Chicken Bowl
#
#                                      choice_description  item_price
# 5     [Fresh Tomato Salsa (Mild), [Rice, Cheese, Sou...       10.98
# 13    [Fresh Tomato Salsa, [Fajita Vegetables, Rice,...       11.25
# 19    [Tomatillo Red Chili Salsa, [Fajita Vegetables...        8.75
# 26    [Roasted Chili Corn Salsa (Medium), [Pinto Bea...        8.49
# 42    [Roasted Chili Corn Salsa, [Rice, Black Beans,...       11.25
# ...                                                 ...         ...
# 4590  [Roasted Chili Corn Salsa, [Rice, Black Beans,...       11.25
# 4591  [Tomatillo Red Chili Salsa, [Rice, Black Beans...        8.75
# 4595  [Tomatillo Green Chili Salsa, [Rice, Black Bea...        8.75
# 4599      [Roasted Chili Corn Salsa, [Cheese, Lettuce]]        8.75
# 4604  [Fresh Tomato Salsa, [Rice, Black Beans, Chees...        8.75
#
# [693 rows x 5 columns]

# %%
import matplotlib.pyplot as plt

# %%
Y =chipo['item_price'].head(20)
X =chipo['item_name'].head(20)
fig = plt.figure(figsize=(10,5))
plt.barh(X,Y)
plt.xlabel('item_price')
plt.ylabel('name')
fig.autofmt_xdate(bottom= 0.3 ,rotation=30)
plt.show()

# %% [markdown]
# ### Sort by the name of the item

# %%
chipo.sort_values(by = "item_name")
# Out:
#       order_id  quantity          item_name  \
# 3389      1360         2  6 Pack Soft Drink
# 341        148         1  6 Pack Soft Drink
# 1849       749         1  6 Pack Soft Drink
# 1860       754         1  6 Pack Soft Drink
# 2713      1076         1  6 Pack Soft Drink
# ...        ...       ...                ...
# 2384       948         1  Veggie Soft Tacos
# 781        322         1  Veggie Soft Tacos
# 2851      1132         1  Veggie Soft Tacos
# 1699       688         1  Veggie Soft Tacos
# 1395       567         1  Veggie Soft Tacos
#
#                                      choice_description item_price
# 3389                                        [Diet Coke]    $12.98
# 341                                         [Diet Coke]     $6.49
# 1849                                             [Coke]     $6.49
# 1860                                        [Diet Coke]     $6.49
# 2713                                             [Coke]     $6.49
# ...                                                 ...        ...
# 2384  [Roasted Chili Corn Salsa, [Fajita Vegetables,...     $8.75
# 781   [Fresh Tomato Salsa, [Black Beans, Cheese, Sou...     $8.75
# 2851  [Roasted Chili Corn Salsa (Medium), [Black Bea...     $8.49
# 1699  [Fresh Tomato Salsa, [Fajita Vegetables, Rice,...    $11.25
# 1395  [Fresh Tomato Salsa (Mild), [Pinto Beans, Rice...     $8.49
#
# [4622 rows x 5 columns]

# %% [markdown]
# ### What was the quantity of the most expensive item ordered?

# %%
chipo.sort_values(by= 'item_price' ,ascending=False).head(1)
# Out:
#       order_id  quantity         item_name  \
# 2624      1042         1  Steak Salad Bowl
#
#                                      choice_description item_price
# 2624  [Fresh Tomato Salsa, [Black Beans, Sour Cream,...     $9.39

# %% [markdown]
# ### How many times was a Veggie Salad Bowl ordered?

# %%
salad_bowl = chipo[chipo.item_name == "Veggie Salad Bowl"]
len(salad_bowl)
# Out:
# 18

# %% [markdown]
# ### How many times did someone order more than one Canned Soda?

# %%
Canned_soda_order= chipo[(chipo.item_name == 'Canned Soda') * (chipo.quantity >1)]

# %%
len(Canned_soda_order)
# Out:
# 20

# %%
X =chipo['item_name'].head(20)
Y =chipo['quantity'].head(20)
fig = plt.figure(figsize=(10,10))
plt.barh(X,Y)
plt.xlabel('quantity')
plt.ylabel('name')
fig.autofmt_xdate(bottom= 0.3 ,rotation=30)
plt.show()
